# %%
import sys
sys.path.append('../')

from build_model import BuildModel
from prepare_data import PrepareData

# %%
x_test, y_test = PrepareData.load_set('test', '../data/processed/')

# %%
my_model = BuildModel()
my_model.load_model('binary_model1', path='../saved_models/')

# %%
my_model.plot_auc(x_test, y_test, treshold=0.5)
# Out:
# 63/63 [==============================] - 38s 581ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       996
#            1       0.79      0.83      0.81      1004
#
#     accuracy                           0.81      2000
#    macro avg       0.81      0.81      0.81      2000
# weighted avg       0.81      0.81      0.81      2000

# %%
my_model = BuildModel()
my_model.load_model('binary_model2', path='../saved_models/')

# %%
my_model.plot_auc(x_test, y_test, treshold=0.5)
# Out:
# 63/63 [==============================] - 38s 577ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.73      0.79       996
#            1       0.77      0.87      0.81      1004
#
#     accuracy                           0.80      2000
#    macro avg       0.81      0.80      0.80      2000
# weighted avg       0.81      0.80      0.80      2000
